# %%
n = int(input("Enter the n value: "))
for i in range(n):
  for j in range(n):
    if i==2 or j==2:
      print("*",end="")
    else:
      print(" ",end ="")
  print()
# Out:
# Enter the n value: 5
#   *
#   *
# *****
#   *
#   *

# %%
for i in range(1,5):
  if i==2:
    break
  print(i)
  print("Loop ended")
# Out:
# 1
# Loop ended

# %%
for i in range(1,5):
  if i==2:
    continue
  print(i)
  print("Loop ended")
# Out:
# 1
# Loop ended
# 3
# Loop ended
# 4
# Loop ended

# %%
name = "BR Concepts Pvt Ltd"
for i in name:
  print(i,end=" ")
# Out:
# B R   C o n c e p t s   P v t   L t d

# %%
name = "BR Concepts Pvt Ltd"
for i in name:
  if i == 'p':
      break
  print(i,end=" ")
# Out:
# B R   C o n c e

# %%
name = "BR Concepts Pvt Ltd"
for i in name:
  if i == 'p':
      pass
  print(i,end=" ")
# Out:
# B R   C o n c e p t s   P v t   L t d
